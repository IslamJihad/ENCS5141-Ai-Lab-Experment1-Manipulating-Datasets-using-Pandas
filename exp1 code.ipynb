# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# create a simple list
a = [1, 7, 2]
# create series from a list
my_Series = pd.Series(a)
print(my_Series)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# a simple dictionary
calories = {"day1": 420, "day2": 380, "day3": 390}
# create series from dictionary
my_Series = pd.Series(calories)
print(my_Series)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
pandas.DataFrame(data=None, index=None, columns=None, dtype=None,
copy=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17048\2734737211.py in <module>
# ----> 1 pandas.DataFrame(data=None, index=None, columns=None, dtype=None,
#       2 copy=None)
#
# NameError: name 'pandas' is not defined

# %%
# Initialize data to a series.
d = pd.Series([10, 20, 30, 40])
# creates Dataframe.
df = pd.DataFrame(d)
# print the data.
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %%
# initialize the data of lists.
data = {'Name': ['Ahmad', 'Ali', 'Omar', 'Hamzah'],'Age': [20, 21, 19, 18]}
# Create DataFrame
df = pd.DataFrame(data)
# Print the output.
print(df)
# Out:
#      Name  Age
# 0   Ahmad   20
# 1     Ali   21
# 2    Omar   19
# 3  Hamzah   18

# %%
data = {
"calories": [420, 380, 390],
"duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     idx  calories  duration
# 0  day1       420        50
# 1  day2       380        40
# 2  day3       390        45

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#     idx  calories  duration
# 0  day1       420        50
# 1  day2       380        40
# 2  day3       390        45

# %%
df = pd.read_csv('data.csv')
df.tail()
# Out:
#     idx  calories  duration
# 0  day1       420        50
# 1  day2       380        40
# 2  day3       390        45

# %%
df.shape
# Out:
# (3, 3)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   idx       3 non-null      object
#  1   calories  3 non-null      int64
#  2   duration  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes
# None

# %%
df = pd.DataFrame({'col_1': list(range(1, 11)), 'col_2':
list(range(11, 21)), 'col_3': list(range(21, 31)), 'col_4':
list(range(31, 41)), 'col_5': list(range(41, 51)), 'col_6':
list(range(51, 61)), 'col_7': list(range(61, 71)), 'col_8':
list(range(71, 81)), 'col_9': list(range(81, 91))})
df
# Out:
#    col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# 0      1     11     21     31     41     51     61     71     81
# 1      2     12     22     32     42     52     62     72     82
# 2      3     13     23     33     43     53     63     73     83
# 3      4     14     24     34     44     54     64     74     84
# 4      5     15     25     35     45     55     65     75     85
# 5      6     16     26     36     46     56     66     76     86
# 6      7     17     27     37     47     57     67     77     87
# 7      8     18     28     38     48     58     68     78     88
# 8      9     19     29     39     49     59     69     79     89
# 9     10     20     30     40     50     60     70     80     90

# %%
print(df.columns)
# Out:
# Index(['col_1', 'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8',
#        'col_9'],
#       dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df['col_2']
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# 5    16
# 6    17
# 7    18
# 8    19
# 9    20
# Name: col_2, dtype: int64

# %%
df[['col_5', 'col_1', 'col_8']]
# Out:
#    col_5  col_1  col_8
# 0     41      1     71
# 1     42      2     72
# 2     43      3     73
# 3     44      4     74
# 4     45      5     75
# 5     46      6     76
# 6     47      7     77
# 7     48      8     78
# 8     49      9     79
# 9     50     10     80

# %%
df[['col_5', 'col_1', 'col_8', 'col_9']]
# Out:
#    col_5  col_1  col_8  col_9
# 0     41      1     71     81
# 1     42      2     72     82
# 2     43      3     73     83
# 3     44      4     74     84
# 4     45      5     75     85
# 5     46      6     76     86
# 6     47      7     77     87
# 7     48      8     78     88
# 8     49      9     79     89
# 9     50     10     80     90

# %%
df.loc[0]
# Out:
# col_1     1
# col_2    11
# col_3    21
# col_4    31
# col_5    41
# col_6    51
# col_7    61
# col_8    71
# col_9    81
# Name: 0, dtype: int64

# %%
df.index = ['row_1', 'row_2', 'row_3', 'row_4', 'row_5', 'row_6','row_7', 'row_8', 'row_9', 'row_10']

# %%
df.loc[['row_6', 'row_2', 'row_9']]
# Out:
#        col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_6      6     16     26     36     46     56     66     76     86
# row_2      2     12     22     32     42     52     62     72     82
# row_9      9     19     29     39     49     59     69     79     89

# %%
df.loc[['row_6', 'row_2', 'row_9', 'row_10']]
# Out:
#         col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_6       6     16     26     36     46     56     66     76     86
# row_2       2     12     22     32     42     52     62     72     82
# row_9       9     19     29     39     49     59     69     79     89
# row_10     10     20     30     40     50     60     70     80     90

# %%
df.loc['row_7':'row_9']
# Out:
#        col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_7      7     17     27     37     47     57     67     77     87
# row_8      8     18     28     38     48     58     68     78     88
# row_9      9     19     29     39     49     59     69     79     89

# %%
#task1
df.loc['row_1':'row_4']
# Out:
#        col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_1      1     11     21     31     41     51     61     71     81
# row_2      2     12     22     32     42     52     62     72     82
# row_3      3     13     23     33     43     53     63     73     83
# row_4      4     14     24     34     44     54     64     74     84

# %%
#task2
a= df[['col_5', 'col_6', 'col_7']]

a.loc['row_10']
# Out:
# col_5    50
# col_6    60
# col_7    70
# Name: row_10, dtype: int64

# %%
df.at['row_6', 'col_3']
# Out:
# 26

# %%
df[3:6]
# Out:
#        col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_4      4     14     24     34     44     54     64     74     84
# row_5      5     15     25     35     45     55     65     75     85
# row_6      6     16     26     36     46     56     66     76     86

# %%
df.iloc[3]
# Out:
# col_1     4
# col_2    14
# col_3    24
# col_4    34
# col_5    44
# col_6    54
# col_7    64
# col_8    74
# col_9    84
# Name: row_4, dtype: int64

# %%
df.iloc[[9, 8, 7]]
# Out:
#         col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_10     10     20     30     40     50     60     70     80     90
# row_9       9     19     29     39     49     59     69     79     89
# row_8       8     18     28     38     48     58     68     78     88

# %%
df.iloc[0, [2, 8, 3]]
# Out:
# col_3    21
# col_9    81
# col_4    31
# Name: row_1, dtype: int64

# %%
df.iat[1, 2]
# Out:
# 22

# %%
#task3
df.iloc[[8,1], [5,6,7,8]]
# Out:
#        col_6  col_7  col_8  col_9
# row_9     59     69     79     89
# row_2     52     62     72     82

# %%
#task4
df.iloc[: , [1,3,7]]
# Out:
#         col_2  col_4  col_8
# row_1      11     31     71
# row_2      12     32     72
# row_3      13     33     73
# row_4      14     34     74
# row_5      15     35     75
# row_6      16     36     76
# row_7      17     37     77
# row_8      18     38     78
# row_9      19     39     79
# row_10     20     40     80

# %%
#task5
df[df['col_2']<=15]
# Out:
#        col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_1      1     11     21     31     41     51     61     71     81
# row_2      2     12     22     32     42     52     62     72     82
# row_3      3     13     23     33     43     53     63     73     83
# row_4      4     14     24     34     44     54     64     74     84
# row_5      5     15     25     35     45     55     65     75     85

# %%
#task6
df[(df['col_2']>15) & (df['col_2']!=19)]
# Out:
#         col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9
# row_6       6     16     26     36     46     56     66     76     86
# row_7       7     17     27     37     47     57     67     77     87
# row_8       8     18     28     38     48     58     68     78     88
# row_10     10     20     30     40     50     60     70     80     90

# %%
# Create a sample dataframe
Biodata = {'Name': ['Ahmad', 'Ali', 'Omar', 'Hamzah'],
'Age': [28, 23, 35, 31],
'Gender': ['M', 'F', 'M', 'F']
}
df = pd.DataFrame(Biodata)
# Save the dataframe to a CSV file
df.to_csv('Biodata.csv', index=False)

# %%
#task7

df.to_csv('BiodataTabSeperate.csv', sep='\t', index=False)

# %%
# Define a dictionary containing Students data
data = {'Name': ['Ahmad', 'Ali', 'Omar', 'Hamzah'],
'Height': [5.1, 6.2, 5.1, 5.2],
'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
df
# Out:
#      Name  Height Qualification
# 0   Ahmad     5.1           Msc
# 1     Ali     6.2            MA
# 2    Omar     5.1           Msc
# 3  Hamzah     5.2           Msc

# %%
# Declare a list that is to be converted into a column
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
# Using 'Address' as the column name and equating it to the list
df['Address'] = address
# Observe the result
df
# Out:
#      Name  Height Qualification    Address
# 0   Ahmad     5.1           Msc      Delhi
# 1     Ali     6.2            MA  Bangalore
# 2    Omar     5.1           Msc    Chennai
# 3  Hamzah     5.2           Msc      Patna

# %%
#Task8

age=  [21, 23, 24, 21] 
df['Age']= age
df
# Out:
#      Name  Height Qualification    Address  Age
# 0   Ahmad     5.1           Msc      Delhi   21
# 1     Ali     6.2            MA  Bangalore   23
# 2    Omar     5.1           Msc    Chennai   24
# 3  Hamzah     5.2           Msc      Patna   21

# %%
import pandas as pd
import numpy as np
technologies = {
'Courses':["Spark","PySpark","Hadoop","Python"],
'Fee' :[20000,25000,26000,22000],
'Duration':['30day','40days',np.nan, None],
'Discount':[1000,2300,1500,1200]
}
indexes=['r1','r2','r3','r4']
df = pd.DataFrame(technologies,index=indexes)
df
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000      NaN      1500
# r4   Python  22000     None      1200

# %%
df1 = df.drop(['r1','r2'])
df1
# Out:
#    Courses    Fee Duration  Discount
# r3  Hadoop  26000      NaN      1500
# r4  Python  22000     None      1200

# %%
df2 = df.drop(index=['r1','r2'])
df2
# Out:
#    Courses    Fee Duration  Discount
# r3  Hadoop  26000      NaN      1500
# r4  Python  22000     None      1200

# %%
df3=df.drop(df.index[[1,3]])
df3
# Out:
#    Courses    Fee Duration  Discount
# r1   Spark  20000    30day      1000
# r3  Hadoop  26000      NaN      1500

# %%
df4=df.drop(df.index[0])
df4
# Out:
#     Courses    Fee Duration  Discount
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000      NaN      1500
# r4   Python  22000     None      1200

# %%
df5=df.drop(df.index[-1])
df5
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000      NaN      1500

# %%
df6=df.drop(df.index[2:])
df6
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300

# %%
df = pd.DataFrame(technologies)
df1 = df.drop(0)
df3 = df.drop([0, 3])
df4 = df.drop(range(0,2))
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  20000    30day      1000
# 1  PySpark  25000   40days      2300
# 2   Hadoop  26000      NaN      1500
# 3   Python  22000     None      1200

# %%
df1
# Out:
#    Courses    Fee Duration  Discount
# 1  PySpark  25000   40days      2300
# 2   Hadoop  26000      NaN      1500
# 3   Python  22000     None      1200

# %%
df2
# Out:
#    Courses    Fee Duration  Discount
# r3  Hadoop  26000      NaN      1500
# r4  Python  22000     None      1200

# %%
df3
# Out:
#    Courses    Fee Duration  Discount
# 1  PySpark  25000   40days      2300
# 2   Hadoop  26000      NaN      1500

# %%
df4
# Out:
#   Courses    Fee Duration  Discount
# 2  Hadoop  26000      NaN      1500
# 3  Python  22000     None      1200

# %%
df.drop(df[df['Fee'] >= 24000].index, inplace = True)
df
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  20000    30day      1000
# 3  Python  22000     None      1200

# %%
df2 = df[df.Fee >= 24000]
df2
# Out:
# Empty DataFrame
# Columns: [Courses, Fee, Duration, Discount]
# Index: []

# %%
df3 = df.loc[df["Fee"] >= 24000]
df3
# Out:
# Empty DataFrame
# Columns: [Courses, Fee, Duration, Discount]
# Index: []

# %%
#task 11
df4 = df[(df.Fee >= 2200) & (df.Discount == 2300)]
df4
# Out:
# Empty DataFrame
# Columns: [Courses, Fee, Duration, Discount]
# Index: []

# %%
#Task 12
df7= df.drop(df[:] == None | (df[:] == np.nan))
df7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     300         #  (xint or xbool) and (yint or bool)
# --> 301         result = op(x, y)
#     302     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'NoneType' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     314             try:
# --> 315                 result = libops.scalar_binop(x, y, op)
#     316             except (
#
# ...

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  20000    30day      1000

# %%
#task13
df8 = df.drop((df[(df['Courses'] == "Spark") | (df['Courses'] == "Hadoop")].index))
df8
# Out:
#   Courses    Fee Duration  Discount
# 3  Python  22000     None      1200

# %%
# Create two sample DataFrames
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})

df2 = pd.DataFrame({'A': ['A0', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B1', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
# Concatenate the DataFrames vertically
result = pd.concat([df1, df2])
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A0  B4  C4  D4
# 1  A5  B1  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
#Task14
result2 = pd.concat([df1, df2], axis=1)
result2
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A0  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B1  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %%
df = pd.merge(df1, df2, on='A')
df
# Out:
#     A B_x C_x D_x B_y C_y D_y
# 0  A0  B0  C0  D0  B4  C4  D4

# %%
df1.merge(df2, on='A', how='left')
# Out:
#     A B_x C_x D_x  B_y  C_y  D_y
# 0  A0  B0  C0  D0   B4   C4   D4
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2  NaN  NaN  NaN
# 3  A3  B3  C3  D3  NaN  NaN  NaN

# %%
df = pd.merge(df1, df2, on= 'A', how='right')
df
# Out:
#     A  B_x  C_x  D_x B_y C_y D_y
# 0  A0   B0   C0   D0  B4  C4  D4
# 1  A5  NaN  NaN  NaN  B1  C5  D5
# 2  A6  NaN  NaN  NaN  B6  C6  D6
# 3  A7  NaN  NaN  NaN  B7  C7  D7

# %%
df = pd.merge(df1, df2,on= 'B', how='outer')
df
# Out:
#    A_x   B  C_x  D_x  A_y  C_y  D_y
# 0   A0  B0   C0   D0  NaN  NaN  NaN
# 1   A1  B1   C1   D1   A5   C5   D5
# 2   A2  B2   C2   D2  NaN  NaN  NaN
# 3   A3  B3   C3   D3  NaN  NaN  NaN
# 4  NaN  B4  NaN  NaN   A0   C4   D4
# 5  NaN  B6  NaN  NaN   A6   C6   D6
# 6  NaN  B7  NaN  NaN   A7   C7   D7

# %%
#TODO
#1
Dinner_df= pd.read_csv('dinner.csv')
lunch_df= pd.read_csv('lunch.csv')
Waiters_df= pd.read_csv('Waiters.csv')
Dinner_df
# Out:
#     Waiter  total_bill   tip smoker  day    time  size
# 0       10       16.99  1.01     No  Sun  Dinner     2
# 1       10       10.34  1.66     No  Sun  Dinner     3
# 2       11       21.01  3.50     No  Sun  Dinner     3
# 3       11       23.68  3.31     No  Sun  Dinner     2
# 4       22       24.59  3.61     No  Sun  Dinner     4
# 5       13       25.29  4.71     No  Sun  Dinner     4
# 6       10        8.77  2.00     No  Sun  Dinner     2
# 7       30       26.88  3.12     No  Sun  Dinner     4
# 8       15       15.04  1.96     No  Sun  Dinner     2
# 9       30       14.78  3.23     No  Sun  Dinner     2
# 10      15       10.27  1.71     No  Sun  Dinner     2
# 11      30       35.26  5.00     No  Sun  Dinner     4
# 12      10       15.42  1.57     No  Sun  Dinner     2
# 13      11       18.43  3.00     No  Sun  Dinner     4
# 14      11       14.83  3.02     No  Sun  Dinner     2
# 15      30       21.58  3.92     No  Sun  Dinner     2
# ...

# %%
lunch_df
# Out:
#     Waiter  total_bill   tip smoker   day   time  size
# 0       10       27.20  4.00     No  Thur  Lunch     4
# 1       10       22.76  3.00     No  Thur  Lunch     2
# 2       11       17.29  2.71     No  Thur  Lunch     2
# 3       11       19.44  3.00    Yes  Thur  Lunch     2
# 4       33       16.66  3.40     No  Thur  Lunch     2
# 5       33       10.07  1.83     No  Thur  Lunch     1
# 6       30       32.68  5.00    Yes  Thur  Lunch     2
# 7       30       15.98  2.03     No  Thur  Lunch     2
# 8       12       34.83  5.17     No  Thur  Lunch     4
# 9       10       13.03  2.00     No  Thur  Lunch     2
# 10      11       18.28  4.00     No  Thur  Lunch     2
# 11      12       24.71  5.85     No  Thur  Lunch     2
# 12      33       21.16  3.00     No  Thur  Lunch     2

# %%
Waiters_df
# Out:
#    Waiter       type
# 0      10  full time
# 1      11  part time
# 2      33  full time
# 3      30  full time
# 4      12  part time
# 5      20  part time

# %%
df1 = pd.concat([Dinner_df, lunch_df])
df1
# Out:
#     Waiter  total_bill   tip smoker   day    time  size
# 0       10       16.99  1.01     No   Sun  Dinner     2
# 1       10       10.34  1.66     No   Sun  Dinner     3
# 2       11       21.01  3.50     No   Sun  Dinner     3
# 3       11       23.68  3.31     No   Sun  Dinner     2
# 4       22       24.59  3.61     No   Sun  Dinner     4
# 5       13       25.29  4.71     No   Sun  Dinner     4
# 6       10        8.77  2.00     No   Sun  Dinner     2
# 7       30       26.88  3.12     No   Sun  Dinner     4
# 8       15       15.04  1.96     No   Sun  Dinner     2
# 9       30       14.78  3.23     No   Sun  Dinner     2
# 10      15       10.27  1.71     No   Sun  Dinner     2
# 11      30       35.26  5.00     No   Sun  Dinner     4
# 12      10       15.42  1.57     No   Sun  Dinner     2
# 13      11       18.43  3.00     No   Sun  Dinner     4
# 14      11       14.83  3.02     No   Sun  Dinner     2
# 15      30       21.58  3.92     No   Sun  Dinner     2
# ...

# %%
#df1 = pd.merge(Dinner_df, lunch_df, how='outer', on='Waiter')
df = pd.merge(Waiters_df, df1, on='Waiter')
df
# Out:
#     Waiter       type  total_bill   tip smoker   day    time  size
# 0       10  full time       16.99  1.01     No   Sun  Dinner     2
# 1       10  full time       10.34  1.66     No   Sun  Dinner     3
# 2       10  full time        8.77  2.00     No   Sun  Dinner     2
# 3       10  full time       15.42  1.57     No   Sun  Dinner     2
# 4       10  full time       16.29  3.71     No   Sun  Dinner     3
# 5       10  full time       15.77  2.23     No   Sat  Dinner     2
# 6       10  full time       27.20  4.00     No  Thur   Lunch     4
# 7       10  full time       22.76  3.00     No  Thur   Lunch     2
# 8       10  full time       13.03  2.00     No  Thur   Lunch     2
# 9       11  part time       21.01  3.50     No   Sun  Dinner     3
# 10      11  part time       23.68  3.31     No   Sun  Dinner     2
# 11      11  part time       18.43  3.00     No   Sun  Dinner     4
# 12      11  part time       14.83  3.02     No   Sun  Dinner     2
# ...

# %%
#2
sum_tips = df.groupby('Waiter')['tip'].sum().reset_index()
sum_tips
# Out:
#    Waiter    tip
# 0      10  21.18
# 1      11  31.04
# 2      12  17.87
# 3      30  22.30
# 4      33  18.99

# %%
#2
part_time_df = df[df['type'] == 'part time']
part_time_df
# Out:
#     Waiter       type  total_bill   tip smoker   day    time  size
# 9       11  part time       21.01  3.50     No   Sun  Dinner     3
# 10      11  part time       23.68  3.31     No   Sun  Dinner     2
# 11      11  part time       18.43  3.00     No   Sun  Dinner     4
# 12      11  part time       14.83  3.02     No   Sun  Dinner     2
# 13      11  part time       10.33  1.67     No   Sun  Dinner     3
# 14      11  part time       17.92  4.08     No   Sat  Dinner     2
# 15      11  part time       20.29  2.75     No   Sat  Dinner     2
# 16      11  part time       17.29  2.71     No  Thur   Lunch     2
# 17      11  part time       19.44  3.00    Yes  Thur   Lunch     2
# 18      11  part time       18.28  4.00     No  Thur   Lunch     2
# 30      12  part time       16.97  3.50     No   Sun  Dinner     3
# 31      12  part time       20.65  3.35     No   Sat  Dinner     3
# 32      12  part time       34.83  5.17     No  Thur   Lunch     4
# ...

# %%
sum_tips_part_time = part_time_df.groupby('Waiter')['tip'].sum().reset_index()
sum_tips_part_time
# Out:
#    Waiter    tip
# 0      11  31.04
# 1      12  17.87

# %%
sum_tips_part_time_sorted = df.groupby('Waiter')['tip'].sum().reset_index()
sum_tips_part_time_sorted
# Out:
#    Waiter    tip
# 0      11  31.04
# 1      12  17.87

# %%
#3
sum_bills= df.groupby('Waiter')['total_bill'].sum().reset_index()
sum_bills
# Out:
#    Waiter  total_bill
# 0      10      146.57
# 1      11      181.50
# 2      12       97.16
# 3      30      147.16
# 4      33      107.13

# %%
#4
size_gt_3_df = df[df['size'] > 3]
size_gt_3_df
# Out:
#     Waiter       type  total_bill   tip smoker   day    time  size
# 6       10  full time       27.20  4.00     No  Thur   Lunch     4
# 11      11  part time       18.43  3.00     No   Sun  Dinner     4
# 19      33  full time       39.42  7.58     No   Sat  Dinner     4
# 24      30  full time       26.88  3.12     No   Sun  Dinner     4
# 26      30  full time       35.26  5.00     No   Sun  Dinner     4
# 32      12  part time       34.83  5.17     No  Thur   Lunch     4

# %%
count_tables = size_gt_3_df.groupby('Waiter')['size'].count().reset_index()
count_tables
# Out:
#    Waiter  size
# 0      10     1
# 1      11     1
# 2      12     1
# 3      30     2
# 4      33     1

# %%
count_tables.rename(columns={'size': 'number_of_tables'}, inplace=True)
count_tables
# Out:
#    Waiter  number_of_tables
# 0      10                 1
# 1      11                 1
# 2      12                 1
# 3      30                 2
# 4      33                 1
